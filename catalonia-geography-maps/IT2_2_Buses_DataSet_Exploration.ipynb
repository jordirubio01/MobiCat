# %% [markdown]
# # Visualització de Dades de Busos Interurbans de Catalunya

# %% [markdown]
# Marc Bosch Manzano
# Novembre 2025

# %% [markdown]
# ## Descripció del dataset

# %% [markdown]
# Gencat. Departament de Territori, Habitatge i Transició Ecològica.
#
# Dades obertes de Catalunya.
#
# [Nombre de viatgers d’autobusos interurbans de Catalunya entre 2012 i 2023](https://analisi.transparenciacatalunya.cat/Transport/Nombre-de-viatgers-d-autobusos-interurbans-de-Cata/xgb3-3duu/about_data)

# %%
import os
import pandas as pd

# %%
directory = r".\territori-gencat"
file_name = r"Nombre_de_viatgers_d’autobusos_interurbans_de_Catalunya_20251030.csv"
file_path = os.path.join(directory, file_name)

bus_df = pd.read_csv(file_path)
bus_df.head(5)
# Out:
#     Any Demarcació               Tipus de transport               Línia  \
# 0  2023  Barcelona  Resta de transport a la demanda          Altres TAD
# 1  2023     Girona  Resta de transport a la demanda          Altres TAD
# 2  2023     Lleida  Resta de transport a la demanda          Altres TAD
# 3  2023  Tarragona  Resta de transport a la demanda          Altres TAD
# 4  2023  Tarragona       Resta de busos interurbans  Altres interurbans
#
#    Origen línia [Codi Municipi] Origen línia [Municipi]  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#    Origen línia [Codi Comarca] Origen línia [Comarca]  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# ...
